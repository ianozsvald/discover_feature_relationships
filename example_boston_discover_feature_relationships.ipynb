# %% [markdown]
# # Explore feature-to-feature relationship in Boston

# %%
import pandas as pd
import seaborn as sns
from sklearn import datasets
import discover
import matplotlib.pyplot as plt

# %%
# watermark is optional - it shows the versions of installed libraries
# so it is useful to confirm your library versions when you submit bug reports to projects
# install watermark using
# %install_ext https://raw.githubusercontent.com/rasbt/watermark/master/watermark.py
# %load_ext watermark
# show a watermark for this environment
# %watermark -d -m -v -p numpy,matplotlib,sklearn -g
# Out:
# 2018-09-17
#
# CPython 3.5.2
# IPython 6.3.1
#
# numpy 1.14.2
# matplotlib 2.2.2
# sklearn 0.19.1
#
# compiler   : GCC 5.4.0 20160609
# system     : Linux
# release    : 4.4.0-134-generic
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 8
# interpreter: 64bit
# Git hash   : 7c969c1c4551ca860ef2a5473d90df8e15db9d3b

# %%
example_dataset = datasets.load_boston()
df_boston = pd.DataFrame(example_dataset.data, columns=example_dataset.feature_names)
df_boston['target'] = example_dataset.target

df = df_boston
cols = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'B', 'LSTAT', 'target']
classifier_overrides = set()

df = df_boston
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %% [markdown]
# # Discover non-linear relationships
#
# _Github note_ colours for `style` don't show up in Github, you'll have to grab a local copy of the Notebook.
#
# * NOX predicts RAD, INDUS, TAX and DIS
# * RAD predicts DIS poorly, NOX better, TAX better
# * CRIM predicts RAD but RAD poorly predicts CRIM

# %%
# %time df_results = discover.discover(df[cols].sample(frac=1), classifier_overrides)

fig, ax = plt.subplots(figsize=(12, 8))
sns.heatmap(df_results.pivot(index='target', columns='feature', values='score').fillna(1),
            annot=True, center=0, ax=ax, vmin=-0.1, vmax=1, cmap="viridis");
# Out:
# CPU times: user 21.7 s, sys: 4 ms, total: 21.7 s
# Wall time: 21.7 s

# %%
# we can also output a DataFrame using style (note - doesn't render on github with colours, look at a local Notebook!)
df_results.pivot(index='target', columns='feature', values='score').fillna(1) \
.style.background_gradient(cmap="viridis", low=0.7, axis=1) \
.set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row0_col0 {
#             background-color:  #fde725;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row0_col1 {
#             background-color:  #25848e;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row0_col2 {
#             background-color:  #1f958b;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row0_col3 {
#             background-color:  #2cb17e;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row0_col4 {
#             background-color:  #65cb5e;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row0_col5 {
#             background-color:  #86d549;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row0_col6 {
#             background-color:  #22a785;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row0_col7 {
#             background-color:  #89d548;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row0_col8 {
#             background-color:  #54c568;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row0_col9 {
#             background-color:  #2cb17e;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row0_col10 {
#             background-color:  #297b8e;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row0_col11 {
#             background-color:  #70cf57;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row0_col12 {
#             background-color:  #3aba76;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row0_col13 {
#             background-color:  #22a785;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row1_col0 {
#             background-color:  #27808e;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row1_col1 {
#             background-color:  #fde725;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row1_col2 {
#             background-color:  #1fa088;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row1_col3 {
#             background-color:  #1f968b;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row1_col4 {
#             background-color:  #277f8e;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row1_col5 {
#             background-color:  #32b67a;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row1_col6 {
#             background-color:  #297b8e;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row1_col7 {
#             background-color:  #5cc863;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row1_col8 {
#             background-color:  #2eb37c;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row1_col9 {
#             background-color:  #2eb37c;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row1_col10 {
#             background-color:  #287c8e;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row1_col11 {
#             background-color:  #31b57b;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row1_col12 {
#             background-color:  #20a486;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row1_col13 {
#             background-color:  #228b8d;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row2_col0 {
#             background-color:  #297b8e;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row2_col1 {
#             background-color:  #21918c;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row2_col2 {
#             background-color:  #fde725;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row2_col3 {
#             background-color:  #26828e;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row2_col4 {
#             background-color:  #25ac82;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row2_col5 {
#             background-color:  #44bf70;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row2_col6 {
#             background-color:  #297b8e;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row2_col7 {
#             background-color:  #35b779;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row2_col8 {
#             background-color:  #40bd72;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row2_col9 {
#             background-color:  #3aba76;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row2_col10 {
#             background-color:  #228c8d;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row2_col11 {
#             background-color:  #3aba76;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row2_col12 {
#             background-color:  #3bbb75;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row2_col13 {
#             background-color:  #1fa188;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row3_col0 {
#             background-color:  #20a486;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row3_col1 {
#             background-color:  #228d8d;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row3_col2 {
#             background-color:  #1fa188;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row3_col3 {
#             background-color:  #fde725;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row3_col4 {
#             background-color:  #218e8d;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row3_col5 {
#             background-color:  #5ac864;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row3_col6 {
#             background-color:  #23898e;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row3_col7 {
#             background-color:  #77d153;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row3_col8 {
#             background-color:  #52c569;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row3_col9 {
#             background-color:  #5ac864;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row3_col10 {
#             background-color:  #297b8e;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row3_col11 {
#             background-color:  #5ac864;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row3_col12 {
#             background-color:  #22a785;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row3_col13 {
#             background-color:  #25ab82;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row4_col0 {
#             background-color:  #5ac864;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row4_col1 {
#             background-color:  #25838e;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row4_col2 {
#             background-color:  #1e9c89;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row4_col3 {
#             background-color:  #37b878;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row4_col4 {
#             background-color:  #fde725;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row4_col5 {
#             background-color:  #d2e21b;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row4_col6 {
#             background-color:  #20928c;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row4_col7 {
#             background-color:  #cae11f;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row4_col8 {
#             background-color:  #7fd34e;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row4_col9 {
#             background-color:  #3fbc73;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row4_col10 {
#             background-color:  #297b8e;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row4_col11 {
#             background-color:  #addc30;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row4_col12 {
#             background-color:  #7ad151;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row4_col13 {
#             background-color:  #218f8d;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row5_col0 {
#             background-color:  #24aa83;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row5_col1 {
#             background-color:  #26818e;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row5_col2 {
#             background-color:  #23898e;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row5_col3 {
#             background-color:  #2db27d;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row5_col4 {
#             background-color:  #56c667;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row5_col5 {
#             background-color:  #fde725;
#         }    #T_30a03dc2_ba85_11e8_8e2e_e4a4716665e3row5_co

# %% [markdown]
# # We can drill in to some of the discovered relationships

# %%
print(example_dataset.DESCR)
# Out:
# Boston House Prices dataset
# ===========================
#
# Notes
# ------
# Data Set Characteristics:
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive
#
#     :Median Value (attribute 14) is usually the target
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# http://archive.ics.uci.edu/ml/datasets/Housing
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# **References**
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.
#    - many more! (see http://archive.ics.uci.edu/ml/datasets/Housing)

# %%
# NOX (pollution) predicts AGE of properties - lower pollution means more houses built after 1940 than before
df.plot(kind="scatter", x="NOX", y="AGE", alpha=0.1);

# %%
# NOX (pollution) predicts DIStance, lower pollution means larger distance to places of work
df.plot(kind="scatter", x="NOX", y="DIS", alpha=0.1);

# %%
# More lower-status people means lower house prices
ax = df.plot(kind="scatter", x="LSTAT", y="target", alpha=0.1);

# %%
# closer to employment centres means higher proportion of owner-occupied residences built prior to 1940 (i.e. more older houses)
ax = df.plot(kind="scatter", x="DIS", y="AGE", alpha=0.1);

# %% [markdown]
# # Try correlations
#
# Correlations can give us a direction and information about linear and rank-based relationships which we won't get from RF.

# %% [markdown]
# ## Pearson (linear)

# %%
df_results = discover.discover(df[cols], classifier_overrides, method='pearson')

df_results.pivot(index='target', columns='feature', values='score').fillna(1) \
.style.background_gradient(cmap="viridis", axis=1) \
.set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row0_col0 {
#             background-color:  #fde725;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row0_col1 {
#             background-color:  #38588c;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row0_col2 {
#             background-color:  #228b8d;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row0_col3 {
#             background-color:  #28ae80;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row0_col4 {
#             background-color:  #440154;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row0_col5 {
#             background-color:  #77d153;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row0_col6 {
#             background-color:  #69cd5b;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row0_col7 {
#             background-color:  #98d83e;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row0_col8 {
#             background-color:  #1fa287;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row0_col9 {
#             background-color:  #3fbc73;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row0_col10 {
#             background-color:  #365d8d;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row0_col11 {
#             background-color:  #4cc26c;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row0_col12 {
#             background-color:  #482576;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row0_col13 {
#             background-color:  #3f4788;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row1_col0 {
#             background-color:  #472a7a;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row1_col1 {
#             background-color:  #fde725;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row1_col2 {
#             background-color:  #306a8e;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row1_col3 {
#             background-color:  #471164;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row1_col4 {
#             background-color:  #20928c;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row1_col5 {
#             background-color:  #481769;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row1_col6 {
#             background-color:  #481467;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row1_col7 {
#             background-color:  #471164;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row1_col8 {
#             background-color:  #423f85;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row1_col9 {
#             background-color:  #440154;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row1_col10 {
#             background-color:  #2a778e;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row1_col11 {
#             background-color:  #440154;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row1_col12 {
#             background-color:  #277f8e;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row1_col13 {
#             background-color:  #1f998a;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row2_col0 {
#             background-color:  #423f85;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row2_col1 {
#             background-color:  #463480;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row2_col2 {
#             background-color:  #fde725;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row2_col3 {
#             background-color:  #481769;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row2_col4 {
#             background-color:  #46085c;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row2_col5 {
#             background-color:  #443983;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row2_col6 {
#             background-color:  #481769;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row2_col7 {
#             background-color:  #424086;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row2_col8 {
#             background-color:  #440154;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row2_col9 {
#             background-color:  #482576;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row2_col10 {
#             background-color:  #424086;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row2_col11 {
#             background-color:  #481c6e;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row2_col12 {
#             background-color:  #481a6c;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row2_col13 {
#             background-color:  #39558c;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row3_col0 {
#             background-color:  #1f988b;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row3_col1 {
#             background-color:  #440256;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row3_col2 {
#             background-color:  #3c4f8a;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row3_col3 {
#             background-color:  #fde725;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row3_col4 {
#             background-color:  #440256;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row3_col5 {
#             background-color:  #1fa188;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row3_col6 {
#             background-color:  #23a983;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row3_col7 {
#             background-color:  #20a386;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row3_col8 {
#             background-color:  #228d8d;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row3_col9 {
#             background-color:  #52c569;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row3_col10 {
#             background-color:  #472a7a;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row3_col11 {
#             background-color:  #42be71;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row3_col12 {
#             background-color:  #472f7d;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row3_col13 {
#             background-color:  #440154;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row4_col0 {
#             background-color:  #450559;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row4_col1 {
#             background-color:  #22a884;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row4_col2 {
#             background-color:  #2c728e;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row4_col3 {
#             background-color:  #3e4989;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row4_col4 {
#             background-color:  #fde725;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row4_col5 {
#             background-color:  #470d60;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row4_col6 {
#             background-color:  #453581;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row4_col7 {
#             background-color:  #440154;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row4_col8 {
#             background-color:  #34608d;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row4_col9 {
#             background-color:  #453581;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row4_col10 {
#             background-color:  #1e9d89;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row4_col11 {
#             background-color:  #472e7c;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row4_col12 {
#             background-color:  #81d34d;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row4_col13 {
#             background-color:  #1fa287;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row5_col0 {
#             background-color:  #75d054;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row5_col1 {
#             background-color:  #404588;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row5_col2 {
#             background-color:  #25848e;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row5_col3 {
#             background-color:  #2fb47c;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row5_col4 {
#             background-color:  #440154;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row5_col5 {
#             background-color:  #fde725;
#         }    #T_30a03dc3_ba85_11e8_8e2e_e4a4716665e3row5_co

# %% [markdown]
# ## Spearman (rank-based)

# %%
df_results = discover.discover(df[cols], classifier_overrides, method='spearman')

df_results.pivot(index='target', columns='feature', values='score').fillna(1) \
.style.background_gradient(cmap="viridis", axis=1) \
.set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row0_col0 {
#             background-color:  #fde725;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row0_col1 {
#             background-color:  #32648e;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row0_col2 {
#             background-color:  #228c8d;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row0_col3 {
#             background-color:  #90d743;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row0_col4 {
#             background-color:  #440154;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row0_col5 {
#             background-color:  #89d548;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row0_col6 {
#             background-color:  #81d34d;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row0_col7 {
#             background-color:  #b2dd2d;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row0_col8 {
#             background-color:  #2db27d;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row0_col9 {
#             background-color:  #3aba76;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row0_col10 {
#             background-color:  #365d8d;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row0_col11 {
#             background-color:  #56c667;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row0_col12 {
#             background-color:  #46327e;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row0_col13 {
#             background-color:  #46327e;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row1_col0 {
#             background-color:  #482374;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row1_col1 {
#             background-color:  #fde725;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row1_col2 {
#             background-color:  #3d4e8a;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row1_col3 {
#             background-color:  #440154;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row1_col4 {
#             background-color:  #25838e;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row1_col5 {
#             background-color:  #481467;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row1_col6 {
#             background-color:  #482677;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row1_col7 {
#             background-color:  #471164;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row1_col8 {
#             background-color:  #404688;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row1_col9 {
#             background-color:  #481668;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row1_col10 {
#             background-color:  #34608d;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row1_col11 {
#             background-color:  #46085c;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row1_col12 {
#             background-color:  #2b748e;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row1_col13 {
#             background-color:  #2a788e;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row2_col0 {
#             background-color:  #433d84;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row2_col1 {
#             background-color:  #481f70;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row2_col2 {
#             background-color:  #fde725;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row2_col3 {
#             background-color:  #453781;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row2_col4 {
#             background-color:  #471365;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row2_col5 {
#             background-color:  #414287;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row2_col6 {
#             background-color:  #481c6e;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row2_col7 {
#             background-color:  #433e85;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row2_col8 {
#             background-color:  #440154;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row2_col9 {
#             background-color:  #46327e;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row2_col10 {
#             background-color:  #443a83;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row2_col11 {
#             background-color:  #481d6f;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row2_col12 {
#             background-color:  #481f70;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row2_col13 {
#             background-color:  #3c508b;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row3_col0 {
#             background-color:  #8ed645;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row3_col1 {
#             background-color:  #3e4989;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row3_col2 {
#             background-color:  #25848e;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row3_col3 {
#             background-color:  #fde725;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row3_col4 {
#             background-color:  #440154;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row3_col5 {
#             background-color:  #9bd93c;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row3_col6 {
#             background-color:  #75d054;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row3_col7 {
#             background-color:  #bade28;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row3_col8 {
#             background-color:  #40bd72;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row3_col9 {
#             background-color:  #95d840;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row3_col10 {
#             background-color:  #3b518b;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row3_col11 {
#             background-color:  #98d83e;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row3_col12 {
#             background-color:  #482475;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row3_col13 {
#             background-color:  #482677;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row4_col0 {
#             background-color:  #471063;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row4_col1 {
#             background-color:  #22a884;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row4_col2 {
#             background-color:  #277e8e;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row4_col3 {
#             background-color:  #481b6d;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row4_col4 {
#             background-color:  #fde725;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row4_col5 {
#             background-color:  #48186a;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row4_col6 {
#             background-color:  #443983;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row4_col7 {
#             background-color:  #440154;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row4_col8 {
#             background-color:  #355e8d;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row4_col9 {
#             background-color:  #404588;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row4_col10 {
#             background-color:  #24aa83;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row4_col11 {
#             background-color:  #453882;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row4_col12 {
#             background-color:  #77d153;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row4_col13 {
#             background-color:  #46c06f;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row5_col0 {
#             background-color:  #86d549;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row5_col1 {
#             background-color:  #39568c;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row5_col2 {
#             background-color:  #228c8d;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row5_col3 {
#             background-color:  #9bd93c;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row5_col4 {
#             background-color:  #440154;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row5_col5 {
#             background-color:  #fde725;
#         }    #T_30a03dc4_ba85_11e8_8e2e_e4a4716665e3row5_co

# %%
ax = df.plot(kind="scatter", x="CRIM", y="LSTAT", alpha=0.1);

# %%
ax = df.plot(kind="scatter", x="CRIM", y="NOX", alpha=0.1);

# %% [markdown]
# ## Mutual Information
# Mutual information represents the amount of information that each column predicts about the others.

# %%
df_results = discover.discover(df[cols], classifier_overrides, method='mutual_information')

df_results.pivot(index='target', columns='feature', values='score').fillna(1) \
.style.background_gradient(cmap="viridis", axis=1) \
.set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_32545266_ba85_11e8_8e2e_e4a4716665e3row0_col0 {
#             background-color:  #fde725;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row0_col1 {
#             background-color:  #440256;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row0_col2 {
#             background-color:  #440154;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row0_col3 {
#             background-color:  #481c6e;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row0_col4 {
#             background-color:  #472a7a;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row0_col5 {
#             background-color:  #481d6f;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row0_col6 {
#             background-color:  #481c6e;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row0_col7 {
#             background-color:  #472c7a;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row0_col8 {
#             background-color:  #481467;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row0_col9 {
#             background-color:  #470e61;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row0_col10 {
#             background-color:  #450559;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row0_col11 {
#             background-color:  #481769;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row0_col12 {
#             background-color:  #471164;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row0_col13 {
#             background-color:  #481769;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row1_col0 {
#             background-color:  #450559;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row1_col1 {
#             background-color:  #fde725;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row1_col2 {
#             background-color:  #440154;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row1_col3 {
#             background-color:  #470d60;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row1_col4 {
#             background-color:  #481769;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row1_col5 {
#             background-color:  #481769;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row1_col6 {
#             background-color:  #46085c;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row1_col7 {
#             background-color:  #481668;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row1_col8 {
#             background-color:  #471164;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row1_col9 {
#             background-color:  #460a5d;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row1_col10 {
#             background-color:  #440154;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row1_col11 {
#             background-color:  #481467;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row1_col12 {
#             background-color:  #46075a;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row1_col13 {
#             background-color:  #470e61;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row2_col0 {
#             background-color:  #470e61;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row2_col1 {
#             background-color:  #471164;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row2_col2 {
#             background-color:  #fde725;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row2_col3 {
#             background-color:  #471365;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row2_col4 {
#             background-color:  #450559;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row2_col5 {
#             background-color:  #38598c;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row2_col6 {
#             background-color:  #440154;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row2_col7 {
#             background-color:  #3b528b;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row2_col8 {
#             background-color:  #38588c;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row2_col9 {
#             background-color:  #472c7a;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row2_col10 {
#             background-color:  #440154;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row2_col11 {
#             background-color:  #424186;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row2_col12 {
#             background-color:  #440154;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row2_col13 {
#             background-color:  #482374;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row3_col0 {
#             background-color:  #481c6e;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row3_col1 {
#             background-color:  #460a5d;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row3_col2 {
#             background-color:  #440154;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row3_col3 {
#             background-color:  #fde725;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row3_col4 {
#             background-color:  #482878;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row3_col5 {
#             background-color:  #375a8c;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row3_col6 {
#             background-color:  #471365;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row3_col7 {
#             background-color:  #3b528b;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row3_col8 {
#             background-color:  #3e4c8a;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row3_col9 {
#             background-color:  #46337f;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row3_col10 {
#             background-color:  #460b5e;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row3_col11 {
#             background-color:  #3a538b;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row3_col12 {
#             background-color:  #481b6d;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row3_col13 {
#             background-color:  #481a6c;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row4_col0 {
#             background-color:  #482979;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row4_col1 {
#             background-color:  #481467;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row4_col2 {
#             background-color:  #440154;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row4_col3 {
#             background-color:  #482979;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row4_col4 {
#             background-color:  #fde725;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row4_col5 {
#             background-color:  #3e4989;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row4_col6 {
#             background-color:  #481467;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row4_col7 {
#             background-color:  #365c8d;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row4_col8 {
#             background-color:  #424186;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row4_col9 {
#             background-color:  #482878;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row4_col10 {
#             background-color:  #46085c;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row4_col11 {
#             background-color:  #424186;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row4_col12 {
#             background-color:  #482374;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row4_col13 {
#             background-color:  #481769;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row5_col0 {
#             background-color:  #482576;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row5_col1 {
#             background-color:  #471365;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row5_col2 {
#             background-color:  #440154;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row5_col3 {
#             background-color:  #2a788e;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row5_col4 {
#             background-color:  #33628d;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row5_col5 {
#             background-color:  #fde725;
#         }    #T_32545266_ba85_11e8_8e2e_e4a4716665e3row5_co

# %%
ax = df.plot(kind="scatter", x="TAX", y="INDUS", alpha=0.1)

# %%
ax = df.plot(kind="scatter", x="TAX", y="NOX", alpha=0.1)
